# %%
import numpy as np
import os,sys
from matplotlib import pyplot as plt

# %%
image_arr = np.load('AIS_001.npy')
image_arr.shape
# Out:
# (32, 128, 128)

# %%
tmp_img = np.copy(image_arr[16,:,:])
plt.figure()
im = plt.imshow(tmp_img, cmap=plt.cm.bone)

# %%
image_arr
# Out:
# array([[[ -887,  -928, -1008, ...,  -984, -1024, -1005],
#         [ -982, -1006, -1024, ...,  -950, -1023, -1023],
#         [ -969,  -916,  -832, ...,  -913, -1018, -1023],
#         ...,
#         [ -844,  -940,  -978, ...,   -86,  1120,  2248],
#         [ -795,  -899,  -920, ...,    64,  1372,  1938],
#         [ -890,  -964,  -854, ...,   609,  1845,  1937]],
#
#        [[ -951,  -982, -1006, ..., -1016, -1024,  -960],
#         [ -889,  -987, -1019, ..., -1018, -1006,  -996],
#         [ -959,  -925,  -855, ...,  -994,  -993, -1024],
#         ...,
#         [ -940,  -976,  -854, ...,  -133,   949,  2167],
#         [ -802,  -826,  -917, ...,   109,  1338,  2091],
#         [ -881,  -809,  -869, ...,   506,  1927,  2145]],
#
#        [[ -913,  -951,  -933, ..., -1024, -1008,  -928],
#         [ -895,  -888,  -906, ..., -1023,  -987,  -965],
#         [ -958,  -937,  -988, ..., -1004,  -999,  -994],
#         ...,
#         [ -879,  -865,  -837, ...,  -244,   801,  2093],
# ...
